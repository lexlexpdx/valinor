# %% [markdown]
# # Homework 3: This HW is based on the class material for weeks 5 and 6
#
# ## HWs have a combination of concepts, math, and lab-based (i.e., programming) questions. Many final exam questions would be close to HW questions.
#
# ## Instructions:
#
# Place the answer to your code only in the area specified. Also, make sure to run all your code (e.g., if you are running the code on your local machine, go to Run tab (top left) and select "Restart Kernel and Run All Cells"). This should plot all outputs including your answers to homework questions. After this, go to file (top left) and select "Print". Save your file as a PDF and upload the PDF to Canvas. This is one way to generate a PDF. You can also search for other methods to generate a PDF from Jupyter. $\text{\bf{Students who do not upload a PDF would not get any points for this homework.}}$

# %% [markdown]
# ## Question 1 (3 points)
#
# A data scientist is hired by a
# political candidate to predict who will donate
# money.  The data scientist decides to use two predictors for each possible donor:
#
# - $x_1$ = the income of the person (in tens of thousands of dollars), and
# - $x_2$ = the number of websites with similar political views as the candidate the person follows on Facebook.
#
# To train the model, the scientist
# tries to solicit donations from a randomly selected subset
# of people and records who donates or not.  She obtains the following data:
#
# \begin{array}{l c r}
# \text{Income (ten thousands \$), $x_{i1}$} & 3 & 5 & 7 & 8 & 10\\
# \hline
# \text{Num websites, $x_{i2}$ } & 0  & 1 & 1 & 2 & 1 \\
# \text{Donate (1=yes or 0=no), $y_i$} & 0  & 1 & 0 & 1 & 1
# \end{array}
#
#
# Answer the three questions below. You can solve all of these by hand or you can code with Python.
#
# 1a) (1 point) Draw a scatter plot of the data labeling the two classes with different markers.
#
# 1b) (1 point) Find a linear classifier that makes at most one error on the training data.
# The classifier should be of the form,
#
# \begin{equation}
#     \hat{y}_i = \begin{cases}
#         1 & \mbox{if } z_i > 0\\
#         0 & \mbox{if } z_i < 0,
#         \end{cases}
#     \quad
#     z_i = {\bf{w}^T\bf{x_i}} + b.
# \end{equation}
#
# What is the weight vector $\bf{w}$ and bias $b$ in your classifier?
#
# 1c) (1 point) Now consider a logistic model of the form,
#
# \begin{equation}
#     P(y_i=1|{\bf{x_i}}) = \frac{1}{1+e^{-z_i}}, \quad z_i = {\bf{w}}^T{\bf{x_i}} +b.
# \end{equation}
#
# Using $\bf{w}$ and $b$ from the previous part, which sample $i$ is the least likely (i.e., $P(y_i|{\bf{x_i}})$ is the smallest).

# %% [markdown]
# ## Question 2 (2 points)
#
# Compute the following gradients:
#
# 2a) (1 point) $\partial f({\bf{x}})/\partial {\bf{x}}$ of the function below:
# \begin{equation}
# f({\bf{x}}) =  x_1+x_2x_3+2x_1^3
# \end{equation}
#
# 2b) (1 point) Consider a 1D logistic regression model with suqared error loss. Specifically, suppose you have a single training example $x \in \mathcal{R}$ with labl $y \in \{0,1\}$. Consider the ML model be defined as:
#
# \begin{equation}
# z = wx + b, \quad \hat{y}=\sigma{(z)}, \quad L=\frac{1}{2}(\hat{y}-y)^2
# \end{equation}
#
# Here $\sigma(z)$ is the sigmoid function, that is $\sigma(z)=\frac{1}{1+e^{-z}}$. Now, use the chair rule to compute $\frac{\partial L}{\partial x}$.
#
# Hint 1: $\frac{\partial \sigma}{\partial z} = \frac{\partial (1+e^{-z})^{-1}}{\partial z}= -1(1+e^{-z})^{-2}(-e^{-z})=\frac{e^{-z}}{(1+e^{-z})^2} = \hat{y}(1-\hat{y})$
#
# Hint 2: Your final solution should be a function of $\hat{y}, y,$ and $w$.

# %% [markdown]
# ## Question 3 (1 point)
#
# Consider gradient descent applied to the quadratic function of the form $f(w)=aw^2+bw+c$.
#
# 3a) (0.5 point) Under what condition does graident descent converge to the global minima?
#
# 3b) (0.5 point) Suppose global minima exists. Find the value of the global minimizer $w^*$?

# %% [markdown]
# ## Question 4 (4 points)
#
# Download the banana_quality.csv file from Canvas and place it in the same directory as this homework. For each sample, the dataset has a set of features and one target variable (Quality, which is a categorical variable with two classes of "Good" and "Bad").
#
# 4a) (1 point) Split the dataset into training and test. Use 20% of the dataset for test and load the data.
#
# 4b) (1 point) Apply feature scaling on the training and test feature matrices.
#
# 4c) (1 point) Define a gradient descent function for logistic regression model with inputs and output defined as:
# weights = gradient_descent(X_train, y_train, num_iterations, learning_rate)
#
# 4d) (1 point) Train the model on the dataset and show the test accuracy.

# %% [markdown]
# ## Question 5 (1.5 points): Bonus Question
#
# This is a bonus question. If you lose points in other questions in this homework, the bonus points can help recover some of the lost points. Bonus questions are typically harder than ordinary questions.
#
# Suppose $Y$ is a random variable and assume $\lambda > 0$ is a scalar parameter. The random variable $Y$ has a Poisson distribution with rate $\lambda$, i.e., $Y \sim Poisson(\lambda)$. Here are some characteristics of Poisson distribution:
#
# 1) Poisson distribution is **discrete**. It describes the probability of a count of events (0, 1, 2, 3, …).
#
# 2) The distribution models the probability of observing *k* events in a fixed interval of time/space when events occur independently at a constant average rate.
#
# 3) $\lambda$ is both the **mean** and the **variance** of the distribution.
#
# 4) The probability mass function or PMF (same as probability density function but for discrete random variables) of $Y \sim Poisson(\lambda)$ is:
#
# \begin{equation}
# P(Y=y) = \frac{\lambda^y e^{-\lambda}}{y!}
# \end{equation}
#
# Answer the following questions:
#
# 5a) (0.5 point) What is the value of $E(Y)$.
#
# 5b) (0.5 point) Assume $N$ **independent** obeservations $Y_1, Y_2,..., Y_N$ are drawn, where $Y_i \sim Poisson(\lambda)$ for *i= 1,2,...,N.* Derive the joint PMF P($Y_1,...,Y_N$).
#
# 5c) (0.5 point) Write down the negative log-likelihood function of the joint PMF derived in the previous problem and simplify it into a form that can be minimized. (Hint: remove the terms that do not have $\lambda$.)
