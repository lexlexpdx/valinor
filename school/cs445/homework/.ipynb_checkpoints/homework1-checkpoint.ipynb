# %%
# Lex Albrandt
# CS445
# HW 1

# %%
# jupyter:
#   jupytext:
#     formats: ipynb,py
#   kernelspec:
#     display_name: Python 3
#     language: python
#     name: python3

# %%
import numpy as np
import matplotlib as plt
